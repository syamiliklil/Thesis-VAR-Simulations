# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e504588-b14c-453b-8e35-95a1240db352" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e504588-b14c-453b-8e35-95a1240db352">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving CB POL Cleaned M.xlsx to CB POL Cleaned M.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/CB POL Cleaned M.xlsx')

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Argentina                float64
# Australia                float64
# Brazil                   float64
# Canada                   float64
# China                    float64
# United Kingdom           float64
# Indonesia                float64
# India                    float64
# Japan                    float64
# Korea                    float64
# Mexico                   float64
# Russia                   float64
# Saudi Arabia             float64
# Turkey                   float64
# United States            float64
# Euro area                float64
# South Africa             float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')

# %%
df
# Out:
#             Argentina  Australia  Brazil  Canada  China  United Kingdom  \
# Date
# 2006-03-31       5.00       5.50   16.50    3.75   5.58            4.50
# 2006-04-30       5.00       5.50   15.75    4.00   5.85            4.50
# 2006-05-31       5.50       5.75   15.75    4.25   5.85            4.50
# 2006-06-30       5.75       5.75   15.25    4.25   5.85            4.50
# 2006-07-31       5.75       5.75   14.75    4.25   5.85            4.50
# ...               ...        ...     ...     ...    ...             ...
# 2021-12-31      38.00       0.10    9.25    0.25   3.80            0.25
# 2022-01-31      40.00       0.10    9.25    0.25   3.70            0.25
# 2022-02-28      42.50       0.10   10.75    0.25   3.70            0.50
# 2022-03-31      44.50       0.10   11.75    0.50   3.70            0.75
# 2022-04-30      47.00       0.10   11.75    1.00   3.70            0.75
#
#             Indonesia  India  Japan  Korea  Mexico  Russia  Saudi Arabia  \
# Date
# ...

# %%
df.dtypes
# Out:
# Argentina         float64
# Australia         float64
# Brazil            float64
# Canada            float64
# China             float64
# United Kingdom    float64
# Indonesia         float64
# India             float64
# Japan             float64
# Korea             float64
# Mexico            float64
# Russia            float64
# Saudi Arabia      float64
# Turkey            float64
# United States     float64
# Euro area         float64
# South Africa      float64
# dtype: object

# %%
df_q = df.resample('Q').mean()

# %%
# writing to Excel
datatoexcel = pd.ExcelWriter('CB Pol Q.xlsx')
  
# write DataFrame to excel
df_q.to_excel(datatoexcel)
  
# save the excel
datatoexcel.save()

# %%
from google.colab import files
files.download('/content/CB Pol Q.xlsx')
