# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-94dd9ac3-c520-440a-9b14-fad372b1c916" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-94dd9ac3-c520-440a-9b14-fad372b1c916">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving India.xlsx to India.xlsx

# %%
pip install PyQt5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyQt5
#   Downloading PyQt5-5.15.6-cp36-abi3-manylinux1_x86_64.whl (8.3 MB)
#      |████████████████████████████████| 8.3 MB 4.9 MB/s
# Collecting PyQt5-sip<13,>=12.8
#   Downloading PyQt5_sip-12.10.1-cp37-cp37m-manylinux1_x86_64.whl (338 kB)
#      |████████████████████████████████| 338 kB 39.8 MB/s
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (59.9 MB)
#      |████████████████████████████████| 59.9 MB 91 kB/s
# Installing collected packages: PyQt5-sip, PyQt5-Qt5, PyQt5
# Successfully installed PyQt5-5.15.6 PyQt5-Qt5-5.15.2 PyQt5-sip-12.10.1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Import Statsmodels
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_excel('/content/India.xlsx')

# %%
df.dtypes
# Out:
# Date          object
# CB Claims    float64
# MP           float64
# GDP G        float64
# ER           float64
# MP US        float64
# dtype: object

# %% [markdown]
# ada masalah karena bentuk persenan di GDP Growth, maka dirubah agar tidak persenan

# %%
df['GDP G'] = df['GDP G']*100
df = df.set_index('Date')
df
# Out:
#              CB Claims        MP      GDP G          ER     MP US
# Date
# 31/03/2006   59544.000  6.500000   9.933773   94.860000  4.750000
# 30/06/2006   63434.000  6.583333   8.089748   92.606667  5.000000
# 30/09/2006   66683.000  7.000000  10.127616   92.223333  5.250000
# 31/12/2006   73591.000  7.250000   9.250466   94.856667  5.250000
# 31/03/2007   81142.000  7.500000   9.557228   95.253333  5.250000
# 30/06/2007   94593.000  7.750000  10.727760  101.240000  5.250000
# 30/09/2007  101915.000  7.750000   9.110817  101.906667  5.083333
# 31/12/2007  121377.000  7.750000  10.897586  100.926667  4.416667
# 31/03/2008  138989.000  7.750000   8.537632   98.823333  2.750000
# 30/06/2008  143257.000  8.000000   6.974694   95.620000  2.000000
# 30/09/2008  143672.000  9.000000   6.003424   94.503333  2.000000
# 31/12/2008  134772.000  7.333333   2.666428   90.820000  0.708333
# 31/03/2009  128212.500  5.333333   0.164167   88.513333  0.125000
# 30/06/2009  123756.000  4.750000   4.882523   88.720000  0.125000
# 30/09/2009  127239.000  4.750000   6.633138   89.096667  0.125000
# 31/12/2009  134398.000  4.750000   8.767616   92.040000  0.125000
# 31/03/2010  150854.000  4.833333  13.694729   96.773333  0.125000
# 30/06/2010  159936.000  5.250000  10.039976  101.890000  0.125000
# 30/09/2010  176345.000  5.833333  10.471424   99.813333  0.125000
# 31/12/2010  185621.000  6.166667  10.681642  101.526667  0.125000
# 31/03/2011  196221.000  6.583333   9.851490  101.880000  0.125000
# 30/06/2011  207164.000  7.166667   8.573942  102.410000  0.125000
# 30/09/2011  210058.000  8.083333   5.452604  101.533333  0.125000
# 31/12/2011  201777.000  8.500000   4.739247   94.420000  0.125000
# 31/03/2012  206111.000  8.500000   4.276540   96.420000  0.125000
# 30/06/2012  203202.589  8.000000   4.221217   92.546667  0.125000
# 30/09/2012  210519.186  8.000000   6.095026   92.803333  0.125000
# 31/12/2012  217219.369  8.000000   5.633575   93.246667  0.125000
# 31/03/2013  220346.837  7.666667   5.860671   92.486667  0.125000
# 30/06/2013  212757.016  7.333333   6.117970   91.920000  0.125000
# 30/09/2013  200558.779  7.333333   5.916899   85.970000  0.125000
# 31/12/2013  199879.294  7.750000   6.978560   87.090000  0.125000
# 31/03/2014  200889.011  8.000000   6.515547   86.476667  0.125000
# 30/06/2014  203818.676  8.000000   7.446040   90.230000  0.125000
# 30/09/2014  197632.978  8.000000   7.683643   92.640000  0.125000
# 31/12/2014  192680.692  8.000000   6.980699   93.606667  0.125000
# 31/03/2015  198009.804  7.666667   7.536223   97.066667  0.125000
# 30/06/2015  198973.982  7.416667   7.380751   96.323333  0.125000
# 30/09/2015  189650.307  7.083333   7.402288   97.876667  0.125000
# 31/12/2015  191915.392  6.750000   7.929637   98.836667  0.208333
# 31/03/2016  188764.388  6.750000   9.222507   97.086667  0.375000
# 30/06/2016  180179.791  6.500000   8.836548   97.576667  0.375000
# 30/09/2016  181348.591  6.500000   9.312486   99.470000  0.375000
# 31/12/2016  177359.752  6.250000   8.596249  100.763333  0.458333
# 31/03/2017  180929.902  6.250000   6.377468  101.053333  0.708333
# 30/06/2017  181525.915  6.250000   6.668202  103.690000  0.958333
# 30/09/2017  189051.518  6.083333   5.997955  103.806667  1.125000
# 31/12/2017  199233.762  6.000000   6.537097  103.886667  1.208333
# 31/03/2018  198960.726  6.000000   7.953739  100.440000  1.458333
# 30/06/2018  182812.881  6.083333   7.195124   98.520000  1.708333
# 30/09/2018  180102.321  6.416667   6.898828   98.426667  1.958333
# 31/12/2018  179009.185  6.500000   6.450544   96.890000  2.208333
# 31/03/2019  190922.511  6.333333   5.328748   97.550000  2.375000
# 30/06/2019  187492.226  5.916667   5.051141  100.406667  2.375000
# 30/09/2019  184746.856  5.516667   4.663371  101.876667  2.125000
# 31/12/2019  180854.003  5.150000   3.167045  102.563333  1.625000
# 31/03/2020  179075.028  4.900000   2.136609  101.303333  1.125000
# 30/06/2020  168135.242  4.133333 -23.364891  100.213333  0.125000
# 30/09/2020  158535.117  4.000000  -5.288354  101.400000  0.125000
# 31/12/2020  163038.068  4.000000   0.484016  101.866667  0.125000

# %% [markdown]
# Note: the result is P value. x affects y

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(df, alpha=0.05): 
    """Perform Johanson's Cointegration Test and Report Summary"""
    out = coint_johansen(df,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    # Summary
    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(df.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(df)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# CB Claims ::  113.76    > 60.0627   =>   True
# MP     ::  61.71     > 40.1749   =>   True
# GDP G  ::  26.76     > 24.2761   =>   True
# ER     ::  4.79      > 12.3212   =>   False
# MP US  ::  0.0       > 4.1296    =>   False

# %% [markdown]
# When two or more time series are cointegrated, it means they have a long run, statistically significant relationship.
#
# This is the basic premise on which Vector Autoregression(VAR) models is based on. So, it’s fairly common to implement the cointegration test before starting to build VAR models.

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in df.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "CB Claims"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.8592
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.548
#  Critical value 5%     = -2.913
#  Critical value 10%    = -2.594
#  => P-Value = 0.0503. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "MP"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.9756
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.553
#  Critical value 5%     = -2.915
#  Critical value 10%    = -2.595
#  => P-Value = 0.2974. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GDP G"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.7745
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.546
#  Critical value 5%     = -2.912
#  Critical value 10%    = -2.594
#  => P-Value = 0.0032. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "ER"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.2538
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.551
#  Critical value 5%     = -2.914
#  Critical value 10%    = -2.595
#  => P-Value = 0.0171. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "MP US"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.7071
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.548
#  Critical value 5%     = -2.913
#  Critical value 10%    = -2.594
#  => P-Value = 0.0728. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# 1st difference
df = df.diff().dropna()

# %%
cointegration_test(df)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# CB Claims ::  83.11     > 60.0627   =>   True
# MP     ::  43.45     > 40.1749   =>   True
# GDP G  ::  23.52     > 24.2761   =>   False
# ER     ::  6.96      > 12.3212   =>   False
# MP US  ::  1.64      > 4.1296    =>   False

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in df.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "CB Claims"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.3464
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.548
#  Critical value 5%     = -2.913
#  Critical value 10%    = -2.594
#  => P-Value = 0.0004. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "MP"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.4345
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.548
#  Critical value 5%     = -2.913
#  Critical value 10%    = -2.594
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "GDP G"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -6.9683
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.551
#  Critical value 5%     = -2.914
#  Critical value 10%    = -2.595
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "ER"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.7321
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.56
#  Critical value 5%     = -2.918
#  Critical value 10%    = -2.597
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "MP US"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.082
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.548
#  Critical value 5%     = -2.913
#  Critical value 10%    = -2.594
#  => P-Value = 0.001. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    

    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(df, variables = df.columns)
# Out:
#              CB Claims_x    MP_x  GDP G_x    ER_x  MP US_x
# CB Claims_y       1.0000  0.0004   0.0528  0.1361   0.0000
# MP_y              0.0000  1.0000   0.0021  0.0268   0.0000
# GDP G_y           0.0026  0.2722   1.0000  0.1293   0.0000
# ER_y              0.0000  0.0000   0.0041  1.0000   0.0004
# MP US_y           0.0008  0.0118   0.0000  0.1257   1.0000

# %%
train = df
for i in [1,2,3,4,5]:
    model = VAR(train)
    results = model.fit(i)
    print('Order =', i)
    print('AIC: ', results.aic)
    print('BIC: ', results.bic)
    print()
# Out:
# Order = 1
# AIC:  17.757518048760737
# BIC:  18.823264433526127
#
# Order = 2
# AIC:  18.00002616273573
# BIC:  19.971391421172573
#
# Order = 3
# AIC:  17.997147480537265
# BIC:  20.890507038730334
#
# Order = 4
# AIC:  18.203839692494775
# BIC:  22.036021227938583
#
# Order = 5
# AIC:  17.74997892833668
# BIC:  22.53827385525068
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   % freq, ValueWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency Q-DEC will be used.
#   % freq, ValueWarning)

# %% [markdown]
# lags 2 most reasonable, after l2, criteria keep increase

# %%
result = model.fit(2)
result.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 26, Jun, 2022
# Time:                     07:57:17
# --------------------------------------------------------------------
# No. of Equations:         5.00000    BIC:                    19.9714
# Nobs:                     57.0000    HQIC:                   18.7662
# Log likelihood:          -862.398    FPE:                6.72907e+07
# AIC:                      18.0000    Det(Omega_mle):     2.78474e+07
# --------------------------------------------------------------------
# Results for equation CB Claims
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const             1149.867183      1075.797067            1.069           0.285
# L1.CB Claims         0.377747         0.173756            2.174           0.030
# L1.MP              879.725026      3141.391888            0.280           0.779
# L1.GDP G           309.341891       300.047671            1.031           0.303
# L1.ER              239.000428       461.728928            0.518           0.605
# L1.MP US         -1020.637804      4735.280000           -0.216           0.829
# L2.CB Claims        -0.022097         0.179705           -0.123           0.902
# L2.MP              822.921718      3192.712771            0.258           0.797
# L2.GDP G           -34.975726       380.444552           -0.092           0.927
# L2.ER              559.227894       456.396386            1.225           0.220
# L2.MP US          1208.423714      4844.137913            0.249           0.803
# ===============================================================================
#
# Results for equation MP
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               -0.077209         0.062101           -1.243           0.214
# L1.CB Claims         0.000006         0.000010            0.561           0.575
# L1.MP                0.513758         0.181339            2.833           0.005
# L1.GDP G            -0.011122         0.017320           -0.642           0.521
# L1.ER               -0.007063         0.026654           -0.265           0.791
# L1.MP US             0.112193         0.273347            0.410           0.681
# L2.CB Claims         0.000017         0.000010            1.628           0.104
# L2.MP               -0.391275         0.184301           -2.123           0.034
# L2.GDP G            -0.007749         0.021961           -0.353           0.724
# L2.ER                0.005951         0.026346            0.226           0.821
# L2.MP US             0.085667         0.279631            0.306           0.759
# ===============================================================================
#
# Results for equation GDP G
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               -0.623381         0.623556           -1.000           0.317
# L1.CB Claims         0.000022         0.000101            0.218           0.827
# L1.MP               -1.368730         1.820822           -0.752           0.452
# L1.GDP G            -0.629177         0.173914           -3.618           0.000
# L1.ER                0.153054         0.267629            0.572           0.567
# L1.MP US             2.943898         2.744675            1.073           0.283
# L2.CB Claims         0.000096         0.000104            0.920           0.358
# L2.MP               -2.028391         1.850568           -1.096           0.273
# L2.GDP G            -0.586443         0.220514           -2.659           0.008
# L2.ER               -0.174023         0.264538           -0.658           0.511
# L2.MP US             1.935420         2.807772            0.689           0.491
# ===============================================================================
#
# Results for equation ER
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const                0.340939         0.362999            0.939           0.348
# L1.CB Claims         0.000030         0.000059            0.512           0.608
# L1.MP               -0.854370         1.059979           -0.806           0.420
# L1.GDP G             0.014826         0.101243            0.146           0.884
# L1.ER                0.062698         0.155798            0.402           0.687
# L1.MP US             1.836480         1.597793            1.149           0.250
# L2.CB Claims        -0.000079         0.000061           -1.302           0.193
# L2.MP                0.482693         1.077295            0.448           0.654
# L2.GDP G             0.051114         0.128371            0.398           0.691
# L2.ER                0.279330         0.153999            1.814           0.070
# L2.MP US            -0.792921         1.634525           -0.485           0.628
# ===============================================================================
#
# Results for equation MP US
# ===============================================================================
#                   coefficient       std. error           t-stat            prob
# -------------------------------------------------------------------------------
# const               -0.045672         0.045089           -1.013           0.311
# L1.CB Claims        -0.000003         0.000007           -0.359           0.719
# L1.MP               -0.233403         0.131662           -1.773           0.076
# L1.GDP G            -0.019298         0.012576           -1.535           0.125
# L1.ER                0.004176         0.019352            0.216           0.829
# L1.MP US             0.810455         0.198466            4.084           0.000
# L2.CB Claims         0.000005         0.000008            0.639           0.523
# L2.MP                0.038321         0.133813            0.286           0.775
# L2.GDP G            -0.006294         0.015945           -0.395           0.693
# L2.ER               -0.014998         0.019129           -0.784           0.433
# L2.MP US            -0.047269         0.203028           -0.233           0.816
# ===============================================================================
#
# Correlation matrix of residuals
#              CB Claims        MP     GDP G        ER     MP US
# CB Claims     1.000000  0.336866  0.358654  0.370298  0.046759
# MP            0.336866  1.000000  0.302658  0.205547  0.659598
# GDP G         0.358654  0.302658  1.000000  0.230838  0.394268
# ER            0.370298  0.205547  0.230838  1.000000  0.196571
# MP US         0.046759  0.659598  0.394268  0.196571  1.000000

# %% [markdown]
# If there is any correlation left in the residuals, then, there is some pattern in the time series that is still left to be explained by the model. In that case, the typical course of action is to either increase the order of the model or induce more predictors into the system or look for a different algorithm to model the time series.
#
# So, checking for serial correlation is to ensure that the model is sufficiently able to explain the variances and patterns in the time series.

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(result.resid)

for col, val in zip(df.columns, out):
    def adjust(val, length= 6): return str(val).ljust(length)
    print(adjust(col), ':', round(val, 2))
# Out:
# CB Claims : 1.98
# MP     : 1.96
# GDP G  : 1.99
# ER     : 1.99
# MP US  : 1.92

# %% [markdown]
# The value of this statistic can vary between 0 and 4. The closer it is to the value 2, then there is no significant serial correlation. The closer to 0, there is a positive serial correlation, and the closer it is to 4 implies negative serial correlation.
#
# The serial correlation seems quite alright

# %%
result.plot_acorr()
from matplotlib.pyplot import figure

figure(figsize=(8, 6), dpi=80)

# %%
result.plot_forecast(5)
plt.subplots_adjust(left=0.1,
                    bottom=0.2, 
                    right=0.9, 
                    top=1.5, 
                    wspace=1, 
                    hspace=0.2)

# %%
irf = result.irf(10)
irf.plot(orth=False)
figure(figsize=(12, 12), dpi=80)

# %%
irf.plot_cum_effects(orth=False)
figure(figsize=(12, 12), dpi=80)

# %%
fevd = result.fevd(10)
fevd.summary()
# Out:
# FEVD for CB Claims
#      CB Claims        MP     GDP G        ER     MP US
# 0     1.000000  0.000000  0.000000  0.000000  0.000000
# 1     0